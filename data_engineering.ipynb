# %%
import pandas as pd

# %%
df = pd.read_csv("customized-mutants.csv")
df
# Out:
#        projectId  bugId                                         methodName  \
# 0          Chart      1                                                NaN
# 1          Chart      1                                                NaN
# 2          Chart      1                                                NaN
# 3          Chart      1                                                NaN
# 4          Chart      1                                                NaN
# ...          ...    ...                                                ...
# 121443     Chart      1  zoomRangeAxes(double;org.jfree.chart.plot.Plot...
# 121444     Chart      1  zoomRangeAxes(double;org.jfree.chart.plot.Plot...
# 121445     Chart      1  zoomRangeAxes(double;org.jfree.chart.plot.Plot...
# 121446     Chart      1  zoomRangeAxes(double;org.jfree.chart.plot.Plot...
# 121447     Chart      1  zoomRangeAxes(double;org.jfree.chart.plot.Plot...
#
#         mutantId    compositeId  \
# 0          33990  Chart-1/33990
# ...

# %%
df["mutationOperator"]
# Out:
# 0          DOUBLE_LITERAL:DOUBLE_LITERAL
# 1         METHOD_INVOCATION:NULL_LITERAL
# 2            FLOAT_LITERAL:FLOAT_LITERAL
# 3                            DIVIDE:PLUS
# 4                   MULTIPLY:INT_LITERAL
#                        ...
# 121443                    <CALL>:<NO-OP>
# 121444              BOOLEAN_LITERAL:TRUE
# 121445              BOOLEAN_LITERAL:TRUE
# 121446                    <CALL>:<NO-OP>
# 121447              BOOLEAN_LITERAL:TRUE
# Name: mutationOperator, Length: 121448, dtype: object

# %%
df["nodeTypeDetailed"]
# Out:
# 0                        DOUBLE
# 1                         CLASS
# 2                         FLOAT
# 3         (double;double)double
# 4                  (int;int)int
#                   ...
# 121443                     VOID
# 121444                  BOOLEAN
# 121445                  BOOLEAN
# 121446                     VOID
# 121447                  BOOLEAN
# Name: nodeTypeDetailed, Length: 121448, dtype: object

# %%
df["pKillsDom"]
# Out:
# 0         0.00
# 1         0.75
# 2         0.00
# 3         0.00
# 4         0.00
#           ...
# 121443    0.00
# 121444    0.00
# 121445    0.00
# 121446    0.00
# 121447    0.00
# Name: pKillsDom, Length: 121448, dtype: float64
